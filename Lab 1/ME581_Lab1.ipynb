# %% [markdown]
# # Lab 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1.

# %%
# Kd = 0, kff = 1.0, unit step for 10s
data1 = np.loadtxt('data1.csv', delimiter=',')
time = data1[:, 1]
y = data1[:, 2]
r = data1[:, 3]
d = data1[:, 4]
u = data1[:, 5]
usat = data1[:, 6]
plt.plot(time, y)

plt.figure()
plt.step(time, u, '.-', color='blue', markersize=1,
linewidth=1.5, label='u', where='post')
plt.step(time, y, '.-', color='red', markersize=4,
linewidth=0.7, label='y', where='post')
plt.step(time, r, label='reference', where='post')
plt.step(time, d, label='disturbance', where='post')
plt.ylim([-0.5, 3.5])
plt.xlabel('time (s)')
plt.ylabel('Voltage (V)')
plt.title(r'Response to ref step input with PID $k_p=0.0, k_i=0.0, k_d=0.0$ ')
plt.legend( loc='best')

# %% [markdown]
# 2.

# %%
# Kd = 0.2631, unit step for 10s
data1 = np.loadtxt('data2.csv', delimiter=',')
time = data1[:, 1]
y = data1[:, 2]
r = data1[:, 3]
d = data1[:, 4]
u = data1[:, 5]
usat = data1[:, 6]
plt.plot(time, u)

plt.figure()
plt.step(time, u, '.-', color='blue', markersize=1,
linewidth=1.5, label='u', where='post')
plt.step(time, y, '.-', color='red', markersize=4,
linewidth=0.7, label='y', where='post')
plt.step(time, r, label='reference', where='post')
plt.step(time, d, label='disturbance', where='post')
plt.ylim([-0.5, 3.5])
plt.xlabel('time (s)')
plt.ylabel('Voltage (V)')
plt.title(r'Response to ref step input with PID $k_p=0.0, k_i=0.0, k_d=0.2631$ ')
plt.legend( loc='best')

# %% [markdown]
# 3.

# %%
# d_stepmag = 1.0, unit step for 10s
data1 = np.loadtxt('data3.csv', delimiter=',')
time = data1[:, 1]
y = data1[:, 2]
r = data1[:, 3]
d = data1[:, 4]
u = data1[:, 5]
usat = data1[:, 6]
plt.plot(time, y)

plt.figure()
plt.step(time, u, '.-', color='blue', markersize=1,
linewidth=1.5, label='u', where='post')
plt.step(time, y, '.-', color='red', markersize=4,
linewidth=0.7, label='y', where='post')
plt.step(time, r, label='reference', where='post')
plt.step(time, d, label='disturbance', where='post')
plt.ylim([-1, 3.5])
plt.xlabel('time (s)')
plt.ylabel('Voltage (V)')
plt.title(r'Response to ref step input with PID $k_p=0.0, k_i=0.0, k_d=0.2631$ ')
plt.legend( loc='best')
